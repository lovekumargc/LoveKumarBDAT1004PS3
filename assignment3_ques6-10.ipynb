# %% [markdown]
# # Question 5
#
# ### Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014. ### Label both lines and show the legend.
# ### Don't forget to label your axes!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot
# %matplotlib inline

file_name = "us-marriages-divorces-1867-2014.csv"

data = pd.read_csv(file_name, header = 0)

years = data["Year"].values
marriages_per_capita = data["Marriages_per_1000"].values
divorces_per_capita = data["Divorces_per_1000"].values

plt.plot(years, marriages_per_capita)
plt.plot(years, divorces_per_capita)

plt.title("Marriages and divorces per capita in the U.S. between 1900, 1950, and 2000.")
plt.xlabel("Year")
plt.ylabel("Per Capita")

plt.show()

# %% [markdown]
# ### Create a vertical bar chart comparing the number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000.
# ### Don't forget to label your axes!

# %%
data_one = data[data['Year'].apply(lambda x: x in [1900, 1950, 2000])]

years = data_one["Year"].values
marriages_per_capita = data_one["Marriages"].values
divorces_per_capita = data_one["Divorces"].values

data_frame_one = pd.DataFrame(years)
data_frame_two = pd.DataFrame(marriages_per_capita)
data_frame_three = pd.DataFrame(divorces_per_capita)

final_data = pd.concat([data_frame_one, data_frame_two, data_frame_three], axis = 1)

final_data.columns = ["Year", "Marriages", "Divorces"]

plt.bar(years, marriages_per_capita, width = 6)
plt.bar(years, divorces_per_capita, width = 6)

plt.title("Comparison of the number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000.")
plt.xlabel("Year")
plt.ylabel("Per Capita")

plt.show()

# %% [markdown]
# ### Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# ### the actors by their kill count and label each bar with the corresponding actor's name.
# ### Don't forget to label your axes!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot
from matplotlib import pyplot as plt 
# %matplotlib inline


file_name = "actor_kill_counts.csv"

data = pd.read_csv(file_name, header = 0)

data = data.sort_values('Count',ascending=False)

actors = list(data["Actor"]) 
kill_count = list(data["Count"]) 
   
fig = plt.figure()
fig.clf()
ax = fig.add_subplot(111)

fig = plt.figure(1, [100, 100])

ax.set_xlim(-1,10)

plt.setp(ax.get_xticklabels(), fontsize=10, rotation='vertical')
  
plt.bar(actors, kill_count, color ='maroon',  
        width = 0.4) 
  
plt.xlabel("Actors") 
plt.ylabel("Kill Count") 
plt.title("Deadliest actors in the hollywood") 
plt.show()

# %% [markdown]
# ### Create a pie chart showing the fraction of all Roman Emperors that were assassinated.
# ### Make sure that the pie chart is an even circle, labels the categories, and shows the percentage breakdown of the categories.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot
from matplotlib import pyplot as plt 
# %matplotlib inline

file_name = "roman-emperor-reigns.csv"

data = pd.read_csv(file_name, header = 0)

assassinated = data[
    data['Cause_of_Death'].apply(lambda x: 'assassinated' in x.lower())]

assassinated_count = len(assassinated)
other_count = len(data) - assassinated_count
pieLabels              = 'Assasinated', 'Others',

populationShare     = [assassinated_count, other_count]

figureObject, axesObject = plt.subplots()

axesObject.pie(populationShare, labels=pieLabels, autopct='%1.2f', startangle=90)

axesObject.axis('equal')

plt.title("Pie Chart of all Roman Emperors that were assassinated.") 
 
plt.show()

# %% [markdown]
# ### Create a scatter plot showing the relationship between the total revenue earned by arcades and the number of ### Computer Science PhDs awarded in the U.S. between 2000 and 2009.

# %%
file_name = "arcade-revenue-vs-cs-doctorates.csv"

data = pd.read_csv(file_name, header = 0)

arcade_revenue = data['Total Arcade Revenue (billions)'].values
cs_doctorates_awarded = data[
    'Computer Science Doctorates Awarded (US)'].values

plt.title("Relationship between the total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009.") 
plt.xlabel("Computer Science Doctorates Awarded (US)") 
plt.ylabel("Total Arcade Revenue (billions)")

plt.scatter(cs_doctorates_awarded, arcade_revenue)
